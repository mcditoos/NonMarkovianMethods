# %%
from cumulant import csolve
import numpy as np

# %%
w0 = 1
alpha = 0.05
gamma = 5*w0
T = 1*w0
tf = 4
t=np.linspace(0,tf,100)
Hsys = np.array([[1,0],[0,-1]])/2
Q = np.array([[0,1],[1,0]])

# %%
cc = csolve(Hsys,t , 1e-4, alpha, gamma, T, Q, "od")

# %%
rho0=0.5*np.array([[1,1],[1,1]])

# %%
result=cc.evolution(rho0)
# Out:
# Calculating Integrals ...:   0%|          | 0/4 [00:00<?, ?it/s]
# Calculating Integrals ...: 100%|██████████| 4/4 [00:06<00:00,  1.56s/it]
# Calculating the generator ...: 100%|██████████| 4/4 [00:00<00:00, 1010.80it/s]
# Computing Exponential of Generators . . . .: 100%|██████████| 100/100 [00:00<00:00, 8053.73it/s]

# %%
import matplotlib.pyplot as plt

# %%
def population(den, a, b):
    return [den[i][a, b] for i in range(len(den))]

# %%
plt.plot(t, np.abs(population(result, 0, 1)))
#plt.plot(t, np.abs(population(result_h.states, 0, 1)))
plt.show()

# %%
result[-1]
# Out:
# array([[0.36508889+0.j        , 0.31662138+0.02325445j],
#        [0.31662138-0.02325445j, 0.63491111+0.j        ]])

# %%
plt.plot(t,np.abs(population(result,0,1)))
plt.plot(t, np.abs(population(result_h.states, 0, 1)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 plt.plot(t,np.abs(population(result,0,1)))
# ----> 2 plt.plot(t, np.abs(population(result_h.states, 0, 1)))
#       3 plt.show()
#
# NameError: name 'result_h' is not defined
